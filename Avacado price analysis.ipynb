# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('avocado.csv')
a
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
b=a.groupby('year')['Total Volume'].max()
b
# Out:
# year
# 2015    44655461.51
# 2016    52288697.89
# 2017    61034457.10
# 2018    62505646.52
# Name: Total Volume, dtype: float64

# %%
a['Total Volume'].max()
# Out:
# 62505646.52

# %%
a[a['Total Volume']==62505646.52]
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 9097           7  2018-02-04          0.87   62505646.52  21620180.9
#
#              4225        4770   Total Bags  Small Bags  Large Bags  \
# 9097  20445501.03  1066830.22  19373134.37  13384586.8  5719096.61
#
#       XLarge Bags          type  year   region
# 9097    269450.96  conventional  2018  TotalUS

# %%
#a.groupby('AveragePrice')['type'].count()
a['type'].value_counts()
x=['conventional','organic']
y=[9126,9123]
plt.bar(x,y,color='red')
plt.ylabel('count')
plt.xlabel('type')
plt.title('count of type of avacadoes')
plt.show()

# %%
d=a[a['year']==2015]
d
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 11928          46  2015-02-01          1.77       7210.19  1634.42    3012.44
# 11929          47  2015-01-25          1.63       7324.06  1934.46    3032.72
# 11930          48  2015-01-18          1.71       5508.20  1793.64    2078.72
# 11931          49  2015-01-11          1.69       6861.73  1822.28    2377.54
# 11932          50  2015-01-04          1.64       6182.81  1561.30    2958.17
#
# ...

# %%
d['Total Bags'].sum()
# Out:
# 772192237.03

# %%
d['Total Volume'].max()
# Out:
# 44655461.51

# %%
d[d['Total Volume']==44655461.51]
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume         4046  \
# 2699          47  2015-02-01          0.89   44655461.51  18933038.04
#
#              4225        4770  Total Bags  Small Bags  Large Bags  \
# 2699  18956479.74  1381516.11  5384427.62  4216452.03  1121076.47
#
#       XLarge Bags          type  year   region
# 2699     46899.12  conventional  2015  TotalUS

# %%
e=a.query('year==2016')
e
e['Total Volume'].max()
# Out:
# 52288697.89

# %%
e[e['Total Volume']==52288697.89]
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume         4046  \
# 5506          46  2016-02-07          0.76   52288697.89  16573573.78
#
#              4225        4770   Total Bags  Small Bags  Large Bags  \
# 5506  20470572.61  2546439.11  12698112.39  9083373.04  3373077.87
#
#       XLarge Bags          type  year   region
# 5506    241661.48  conventional  2016  TotalUS

# %%
f=a[a['year']==2017]
f['Total Volume'].max()
f[f['Total Volume']==61034457.1]
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume         4046  \
# 8366          47  2017-02-05          0.77    61034457.1  22743616.17
#
#              4225        4770   Total Bags   Small Bags  Large Bags  \
# 8366  20328161.55  1664383.09  16298296.29  12567155.58  3618270.75
#
#       XLarge Bags          type  year   region
# 8366    112869.96  conventional  2017  TotalUS

# %%
a
a['region'].value_counts().sort_values(ascending=False).head(8)
# Out:
# Detroit              338
# SouthCarolina        338
# MiamiFtLauderdale    338
# Nashville            338
# DallasFtWorth        338
# NewOrleansMobile     338
# Sacramento           338
# Southeast            338
# Name: region, dtype: int64

# %%
a.groupby('type')['year'].value_counts()
# Out:
# type          year
# conventional  2017    2862
#               2015    2808
#               2016    2808
#               2018     648
# organic       2017    2860
#               2016    2808
#               2015    2807
#               2018     648
# Name: year, dtype: int64

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')
